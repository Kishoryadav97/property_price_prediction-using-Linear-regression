# %%
Data Description

Building_Class: Identifies the type of dwelling involved in the sale.

Zoning_Class: Identifies the general zoning classification of the sale.

Lot_Extent: Linear feet of street connected to property

Lot_Size: Lot size in square feet

Road_Type: Type of road access to property

Lane_Type: Type of alley access to property

Property_Shape: General shape of property

Land_Outline: Flatness of the property

Utility_Type: Type of utilities available

Lot configuration: Lot configuration

Property_Slope: Slope of property

Neighborhood: Physical locations within Ames city limits

Condition1: Proximity to various conditions

Condition2: Proximity to various conditions (if more than one is present)

House_Type: Type of dwelling

House_Design: Style of dwelling

Overall_Material: Rates the overall material and finish of the house

House_Condition: Rates the overall condition of the house

Construction_Year: Original construction date

Remodel_Year: Remodel date (same as construction date if no remodeling or additions)

Roof_Design: Type of roof

Roof_Quality: Roof material

Exterior1st: Exterior covering on house

Exterior2nd: Exterior covering on house (if more than one material)

Brick_Veneer_Type: Masonry veneer type

Brick_Veneer_Area: Masonry veneer area in square feet

Exterior_Material: Evaluates the quality of the material on the exterior

Exterior_Condition: Evaluates the present condition of the material on the exterior

Foundation_Type: Type of foundation

Basement_Height: Evaluates the height of the basement

Basement_Condition: Evaluates the general condition of the basement

Exposure_Level: Refers to walkout or garden level walls

BsmtFinType1: Rating of basement finished area

BsmtFinSF1: Type 1 finished square feet

BsmtFinType2: Rating of basement finished area (if multiple types)

BsmtFinSF2: Type 2 finished square feet

BsmtUnfSF: Unfinished square feet of basement area

Total_Basement_Area: Total square feet of basement area

Heating_Type: Type of heating

Heating_Quality: Heating quality and condition

Air_Conditioning: Central air conditioning

Electrical_System: Electrical system

First_Floor_Area: First Floor square feet

Second_Floor_Area: Second floor square feet

LowQualFinSF: Low quality finished square feet (all floors)

Grade_Living_Area: Above grade (ground) living area square feet

Underground_Full_Bathroom: Basement full bathrooms

Underground_Half_Bathroom: Basement half bathrooms

Full_Bathroom_Above_Grade: Full bathrooms above grade

Half_Bathroom_Above_Grade: Half baths above grade

Bedroom: Bedrooms above grade (does NOT include basement bedrooms)

Kitchen: Kitchens above grade

Kitchen_Quality: Kitchen quality

Rooms_Above_Grade: Total rooms above grade (does not include bathrooms)

Functional_Rate: Home functionality (Assume typical unless deductions are warranted)

Fireplaces: Number of fireplaces

Fireplace_Quality: quality of fireplaces

Garage: Garage location

Garage_Built_Year: Year garage was built

Garage_Finish_Year: Interior finish of the garage

Garage_Size: Size of garage in car capacity

Garage_Area: Size of garage in square feet

Garage_Qualit: Garage quality

Garage_Condition: Garage condition

Pavedd_Drive: Paved driveway

W_Deck_Area: Wood deck area in square feet

Open_Lobby_Area: Open porch area in square feet

Enclosed_Lobby_Area: Enclosed porch area in square feet

Three_Season_Lobby_Area: Three season porch area in square feet

Screen_Lobby_Area: Screen porch area in square feet

Pool_Area: Pool area in square feet

Pool_Quality: Pool quality

Fence_Quality: quality of fence

Miscellaneous_Feature: Miscellaneous feature not covered in other categories

Miscellaneous_Value: $Value of miscellaneous feature

Month_Sold: Month Sold (MM)

Year_Sold: Year Sold (YYYY)

Sale_Type: Type of sale

Sale_Condition: Condition of sale
# Out:
#   Input In [1]
#     Data Description
#          ^
# SyntaxError: invalid syntax

# %%
import os

# %%
os.chdir("C:\\Users\\Naveen Gandhi\\OneDrive\\Desktop\\Phython\\Datafiles\\Linear Regression")

# %%
os.listdir()
# Out:
# ['Linear Regression with SGD- Updated March 2022-August.ipynb',
#  'Linear_Regression_Property Price Prediction _17_Sept_2022_shared.ipynb',
#  'mtcars.csv',
#  'Property_Price_Test.csv',
#  'Property_Price_Train.csv',
#  'Real estate.csv',
#  'test.csv',
#  'train.csv',
#  'Understanding Diagnostic Plots for Linear Regression Analysis.docx']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
train=pd.read_csv("Property_Price_Train.csv")
test=pd.read_csv("Property_Price_Test.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         1459 non-null   int64
#  1   Building_Class             1459 non-null   int64
#  2   Zoning_Class               1459 non-null   object
#  3   Lot_Extent                 1200 non-null   float64
#  4   Lot_Size                   1459 non-null   int64
#  5   Road_Type                  1459 non-null   object
#  6   Lane_Type                  91 non-null     object
#  7   Property_Shape             1459 non-null   object
#  8   Land_Outline               1459 non-null   object
#  9   Utility_Type               1459 non-null   object
#  10  Lot_Configuration          1459 non-null   object
#  11  Property_Slope             1459 non-null   object
#  12  Neighborhood               1459 non-null   object
# ...

# %%
train.head()
# Out:
#    Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0   1              60          RLD        65.0      8450     Paved       NaN
# 1   2              20          RLD        80.0      9600     Paved       NaN
# 2   3              60          RLD        68.0     11250     Paved       NaN
# 3   4              70          RLD        60.0      9550     Paved       NaN
# 4   5              60          RLD        84.0     14260     Paved       NaN
#
#   Property_Shape Land_Outline Utility_Type  ... Pool_Area Pool_Quality  \
# 0            Reg          Lvl       AllPub  ...         0          NaN
# 1            Reg          Lvl       AllPub  ...         0          NaN
# 2            IR1          Lvl       AllPub  ...         0          NaN
# 3            IR1          Lvl       AllPub  ...         0          NaN
# 4            IR1          Lvl       AllPub  ...         0          NaN
#
#   Fence_Quality Miscellaneous_Feature Miscellaneous_Value Month_Sold  \
# ...

# %%
test.head()
# Out:
#      Id  Building_Class Zoning_Class  Lot_Extent      Lot_Size Road_Type  \
# 0  1461              20          RHD        80.0  16104.819760     Paved
# 1  1462              20          RLD        81.0  15639.150810     Paved
# 2  1463              60          RLD        74.0   3849.428920     Paved
# 3  1464              60          RLD        78.0   4955.447942     Paved
# 4  1465             120          RLD        43.0   3046.604942     Paved
#
#   Lane_Type Property_Shape Land_Outline Utility_Type  ... Screen_Lobby_Area  \
# 0       NaN            Reg          Lvl       AllPub  ...               120
# 1       NaN            IR1          Lvl       AllPub  ...                 0
# 2       NaN            IR1          Lvl       AllPub  ...                 0
# 3       NaN            IR1          Lvl       AllPub  ...                 0
# 4       NaN            IR1          HLS       AllPub  ...               144
#
#   Pool_Area Pool_Quality Fence_Quality Miscellaneous_Feature  \
# ...

# %%
combined_data=train.append(test)

# %%
combined_data.tail()
# Out:
#         Id  Building_Class Zoning_Class  Lot_Extent      Lot_Size Road_Type  \
# 1454  2915             160          RMD        21.0  14584.838440     Paved
# 1455  2916             160          RMD        21.0   8072.991379     Paved
# 1456  2917              20          RLD       160.0   7367.775348     Paved
# 1457  2918              85          RLD        62.0   2203.135444     Paved
# 1458  2919              60          RLD        74.0   6253.431852     Paved
#
#      Lane_Type Property_Shape Land_Outline Utility_Type  ... Pool_Area  \
# 1454       NaN            Reg          Lvl       AllPub  ...         0
# 1455       NaN            Reg          Lvl       AllPub  ...         0
# 1456       NaN            Reg          Lvl       AllPub  ...         0
# 1457       NaN            Reg          Lvl       AllPub  ...         0
# 1458       NaN            Reg          Lvl       AllPub  ...         0
#
#      Pool_Quality Fence_Quality Miscellaneous_Feature Miscellaneous_Value  \
# ...

# %%
combined_data['Zoning_Class']=combined_data['Zoning_Class'].astype('object')
combined_data['Building_Class']=combined_data['Building_Class'].astype('object')
combined_data['Overall_Material']=combined_data['Overall_Material'].astype('object')
combined_data['House_Condition']=combined_data['House_Condition'].astype('object')
#Converting dtypes to object hence they are categorical

# %%
combined_data=combined_data.drop(['Id'],axis=1)
combined_data=combined_data.drop(['Month_Sold'],axis=1)
combined_data=combined_data.drop(['Garage_Built_Year'],axis=1)
combined_data=combined_data.drop(['Garage_Finish_Year'],axis=1)

# %%
combined_data.isnull().sum()
# Out:
# Building_Class            0
# Zoning_Class              4
# Lot_Extent              486
# Lot_Size                  0
# Road_Type                 0
#                        ...
# Miscellaneous_Value       0
# Year_Sold                 0
# Sale_Type                 1
# Sale_Condition            0
# Sale_Price             1459
# Length: 77, dtype: int64

# %%
combined_data.shape
# Out:
# (2918, 77)

# %%
#Imputation
data_num_var=combined_data.select_dtypes(include=np.number)

# %%
data_num_var.isnull().sum().sort_values(ascending=False)
# Out:
# Sale_Price                   1459
# Lot_Extent                    486
# Brick_Veneer_Area              23
# Underground_Full_Bathroom       2
# Underground_Half_Bathroom       2
# Garage_Area                     1
# BsmtFinSF1                      1
# BsmtFinSF2                      1
# BsmtUnfSF                       1
# Total_Basement_Area             1
# Garage_Size                     1
# Three_Season_Lobby_Area         0
# W_Deck_Area                     0
# Open_Lobby_Area                 0
# Enclosed_Lobby_Area             0
# Construction_Year               0
# Screen_Lobby_Area               0
# Miscellaneous_Value             0
# Year_Sold                       0
# Pool_Area                       0
# Bedroom_Above_Grade             0
# Fireplaces                      0
# Rooms_Above_Grade               0
# Kitchen_Above_Grade             0
# Remodel_Year                    0
# Lot_Size                        0
# Full_Bathroom_Above_Grade       0
# ...

# %%
data_num_var.columns
# Out:
# Index(['Lot_Extent', 'Lot_Size', 'Construction_Year', 'Remodel_Year',
#        'Brick_Veneer_Area', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'Total_Basement_Area', 'First_Floor_Area', 'Second_Floor_Area',
#        'LowQualFinSF', 'Grade_Living_Area', 'Underground_Full_Bathroom',
#        'Underground_Half_Bathroom', 'Full_Bathroom_Above_Grade',
#        'Half_Bathroom_Above_Grade', 'Bedroom_Above_Grade',
#        'Kitchen_Above_Grade', 'Rooms_Above_Grade', 'Fireplaces', 'Garage_Size',
#        'Garage_Area', 'W_Deck_Area', 'Open_Lobby_Area', 'Enclosed_Lobby_Area',
#        'Three_Season_Lobby_Area', 'Screen_Lobby_Area', 'Pool_Area',
#        'Miscellaneous_Value', 'Year_Sold', 'Sale_Price'],
#       dtype='object')

# %%
#filling [na values] null values with respective median for the varibales
data_num_var=data_num_var.fillna(data_num_var.median())

# %%
data_num_var.isnull().sum()
# Out:
# Lot_Extent                   0
# Lot_Size                     0
# Construction_Year            0
# Remodel_Year                 0
# Brick_Veneer_Area            0
# BsmtFinSF1                   0
# BsmtFinSF2                   0
# BsmtUnfSF                    0
# Total_Basement_Area          0
# First_Floor_Area             0
# Second_Floor_Area            0
# LowQualFinSF                 0
# Grade_Living_Area            0
# Underground_Full_Bathroom    0
# Underground_Half_Bathroom    0
# Full_Bathroom_Above_Grade    0
# Half_Bathroom_Above_Grade    0
# Bedroom_Above_Grade          0
# Kitchen_Above_Grade          0
# Rooms_Above_Grade            0
# Fireplaces                   0
# Garage_Size                  0
# Garage_Area                  0
# W_Deck_Area                  0
# Open_Lobby_Area              0
# Enclosed_Lobby_Area          0
# Three_Season_Lobby_Area      0
# Screen_Lobby_Area            0
# Pool_Area                    0
# Miscellaneous_Value          0
# ...

# %%
data_cat_var=combined_data.select_dtypes(include='object')

# %%
data_cat_var.isnull().sum().sort_values(ascending=False)
# Out:
# Pool_Quality             2908
# Miscellaneous_Feature    2813
# Lane_Type                2720
# Fence_Quality            2347
# Fireplace_Quality        1419
# Garage_Condition          159
# Garage_Quality            159
# Garage                    157
# Exposure_Level             82
# Basement_Condition         82
# Basement_Height            81
# BsmtFinType2               80
# BsmtFinType1               79
# Brick_Veneer_Type          24
# Zoning_Class                4
# Functional_Rate             2
# Utility_Type                2
# Exterior1st                 1
# Exterior2nd                 1
# Electrical_System           1
# Kitchen_Quality             1
# Sale_Type                   1
# Air_Conditioning            0
# Heating_Quality             0
# Heating_Type                0
# Pavedd_Drive                0
# Building_Class              0
# Exterior_Condition          0
# Foundation_Type             0
# Condition1                  0
# Road_Type                   0
# ...

# %%
data_cat_var.columns
# Out:
# Index(['Building_Class', 'Zoning_Class', 'Road_Type', 'Lane_Type',
#        'Property_Shape', 'Land_Outline', 'Utility_Type', 'Lot_Configuration',
#        'Property_Slope', 'Neighborhood', 'Condition1', 'Condition2',
#        'House_Type', 'House_Design', 'Overall_Material', 'House_Condition',
#        'Roof_Design', 'Roof_Quality', 'Exterior1st', 'Exterior2nd',
#        'Brick_Veneer_Type', 'Exterior_Material', 'Exterior_Condition',
#        'Foundation_Type', 'Basement_Height', 'Basement_Condition',
#        'Exposure_Level', 'BsmtFinType1', 'BsmtFinType2', 'Heating_Type',
#        'Heating_Quality', 'Air_Conditioning', 'Electrical_System',
#        'Kitchen_Quality', 'Functional_Rate', 'Fireplace_Quality', 'Garage',
#        'Garage_Quality', 'Garage_Condition', 'Pavedd_Drive', 'Pool_Quality',
#        'Fence_Quality', 'Miscellaneous_Feature', 'Sale_Type',
#        'Sale_Condition'],
#       dtype='object')

# %%
cols_fillna=['Building_Class', 'Zoning_Class', 'Road_Type', 'Lane_Type',
       'Property_Shape', 'Land_Outline', 'Utility_Type', 'Lot_Configuration',
       'Property_Slope', 'Neighborhood', 'Condition1', 'Condition2',
       'House_Type', 'House_Design', 'Overall_Material', 'House_Condition',
       'Roof_Design', 'Roof_Quality', 'Exterior1st', 'Exterior2nd',
       'Brick_Veneer_Type', 'Exterior_Material', 'Exterior_Condition',
       'Foundation_Type', 'Basement_Height', 'Basement_Condition',
       'Exposure_Level', 'BsmtFinType1', 'BsmtFinType2', 'Heating_Type',
       'Heating_Quality', 'Air_Conditioning', 'Electrical_System',
       'Kitchen_Quality', 'Functional_Rate', 'Fireplace_Quality', 'Garage',
       'Garage_Quality', 'Garage_Condition', 'Pavedd_Drive', 'Pool_Quality',
       'Fence_Quality', 'Miscellaneous_Feature', 'Sale_Type']

# %%
#Using Fo loop to fill na values in categorical varibles with mode[most frequently]
for i in cols_fillna:
    data_cat_var[i].fillna(data_cat_var[i].mode()[0],inplace=True)

# %%
data_cat_var.isnull().sum()
# Out:
# Building_Class           0
# Zoning_Class             0
# Road_Type                0
# Lane_Type                0
# Property_Shape           0
# Land_Outline             0
# Utility_Type             0
# Lot_Configuration        0
# Property_Slope           0
# Neighborhood             0
# Condition1               0
# Condition2               0
# House_Type               0
# House_Design             0
# Overall_Material         0
# House_Condition          0
# Roof_Design              0
# Roof_Quality             0
# Exterior1st              0
# Exterior2nd              0
# Brick_Veneer_Type        0
# Exterior_Material        0
# Exterior_Condition       0
# Foundation_Type          0
# Basement_Height          0
# Basement_Condition       0
# Exposure_Level           0
# BsmtFinType1             0
# BsmtFinType2             0
# Heating_Type             0
# Heating_Quality          0
# Air_Conditioning         0
# Electrical_System        0
# Kitchen_Quality          0
# ...

# %%
#Manual Plotting
#Zoning Class and its impact on price of the property

sns.boxplot(y=data_num_var['Sale_Price'],x=data_cat_var['Zoning_Class']);plt.show()

# %%
#Lot Configuration and its impact on price of the property

sns.boxplot(y=data_num_var['Sale_Price'],x=data_cat_var['Lot_Configuration']);plt.show()

# %%
#Usin for loop to visulize all ctegotical varibles with respect to sale_price for comparision 
from matplotlib.pyplot import figure
for i in data_cat_var.columns:
    figure()
    sns.boxplot(y=data_num_var['Sale_Price'],x=data_cat_var[i])

# %%
#for numeric varible

from matplotlib.pyplot import figure
for i in data_num_var.columns:
    figure()
    sns.histplot(data_num_var[i])

# %%
#Standardization

from sklearn.preprocessing import MinMaxScaler
minmax=MinMaxScaler()
data_num_var=minmax.fit_transform(data_num_var)

# %%
data_num_var=pd.DataFrame(data_num_var)

# %%
data_num_var.columns=['Lot_Extent', 'Lot_Size', 'Construction_Year', 'Remodel_Year',
       'Brick_Veneer_Area', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
       'Total_Basement_Area', 'First_Floor_Area', 'Second_Floor_Area',
       'LowQualFinSF', 'Grade_Living_Area', 'Underground_Full_Bathroom',
       'Underground_Half_Bathroom', 'Full_Bathroom_Above_Grade',
       'Half_Bathroom_Above_Grade', 'Bedroom_Above_Grade',
       'Kitchen_Above_Grade', 'Rooms_Above_Grade', 'Fireplaces', 'Garage_Size',
       'Garage_Area', 'W_Deck_Area', 'Open_Lobby_Area', 'Enclosed_Lobby_Area',
       'Three_Season_Lobby_Area', 'Screen_Lobby_Area', 'Pool_Area',
       'Miscellaneous_Value', 'Year_Sold', 'Sale_Price']

# %%
data_num_var.describe()
# Out:
#         Lot_Extent     Lot_Size  Construction_Year  Remodel_Year  \
# count  2918.000000  2918.000000        2918.000000   2918.000000
# mean      0.164679     0.065873           0.719673      0.571185
# std       0.073018     0.035938           0.219539      0.348248
# min       0.000000     0.000000           0.000000      0.000000
# 25%       0.133562     0.051932           0.588768      0.250000
# 50%       0.160959     0.063164           0.731884      0.716667
# 75%       0.195205     0.075655           0.934783      0.900000
# max       1.000000     1.000000           1.000000      1.000000
#
#        Brick_Veneer_Area   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  \
# count        2918.000000  2918.000000  2918.000000  2918.000000
# mean            0.063394     0.078183     0.032427     0.240105
# std             0.111797     0.080715     0.110845     0.188132
# min             0.000000     0.000000     0.000000     0.000000
# ...

# %%
data_cat_var=pd.get_dummies(data_cat_var,drop_first=True)

# %%
data_cat_var.describe()
# Out:
#        Building_Class  Overall_Material  House_Condition  Zoning_Class_FVR  \
# count     2918.000000       2918.000000      2918.000000       2918.000000
# mean        57.150446          6.089445         5.564428          0.047635
# std         42.519354          1.410045         1.113292          0.213030
# min         20.000000          1.000000         1.000000          0.000000
# 25%         20.000000          5.000000         5.000000          0.000000
# 50%         50.000000          6.000000         5.000000          0.000000
# 75%         70.000000          7.000000         6.000000          0.000000
# max        190.000000         10.000000         9.000000          1.000000
#
#        Zoning_Class_RHD  Zoning_Class_RLD  Zoning_Class_RMD  Road_Type_Paved  \
# count       2918.000000       2918.000000       2918.000000      2918.000000
# mean           0.008910          0.777245          0.157642         0.995888
# ...

# %%
data_num_var=data_num_var.reset_index()
data_cat_var=data_cat_var.reset_index()

# %%
combined_data=pd.concat([data_num_var,data_cat_var],axis=1);
combined_data.shape
# Out:
# (2918, 253)

# %%
train_df=combined_data.iloc[0:1459,:]
test_df=combined_data.iloc[1459:,:]

# %%
X=train_df.drop(['Sale_Price'],axis=1)
Y=train_df['Sale_Price']

# %%
#Splitting the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=.30)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1021, 252), (438, 252), (1021,), (438,))

# %%
from statsmodels.api import OLS
model_defination=OLS(y_train,x_train)
model_building=model_defination.fit()
print(model_building.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Sale_Price   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     51.67
# Date:                Wed, 15 Feb 2023   Prob (F-statistic):               0.00
# Time:                        20:35:48   Log-Likelihood:                 2229.2
# No. Observations:                1021   AIC:                            -3992.
# Df Residuals:                     788   BIC:                            -2844.
# Df Model:                         232
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# index                       1.765e-07    1.3e-06      0.136      0.892   -2.37e-06    2.72e-06
# ...

# %%
prediction=model_building.predict(x_test);
prediction
# Out:
# 244     0.281549
# 810     0.190236
# 404     0.175849
# 154     0.094189
# 305     0.345762
#           ...
# 805     0.281022
# 1100   -0.000279
# 601     0.129751
# 610     0.406768
# 1162    0.129845
# Length: 438, dtype: float64

# %%
#check for errors
import statsmodels.api as sm
sm.qqplot(model_building.resid,line='s')

# %%
sns.histplot(model_building.resid)
#erros or residuals are normally distributed
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
#checking for Hetroscadaticity
#Since the p_value is less than significance value(alpha=5%) we can say the residuals are homoscadaticity(residual has equal vaiance)
from statsmodels.compat import lzip
import statsmodels.stats.api as sm

names=['Lagrange multiplier statistic','p_value',
      'f-value','f p-value']
test=sm.het_breuschpagan(model_building.resid,model_building.model.exog)

lzip(names,test)
# Out:
# [('Lagrange multiplier statistic', 689.2880919067135),
#  ('p_value', 1.5607494510007597e-42),
#  ('f-value', 7.057939735871896),
#  ('f p-value', 6.407624774326132e-96)]

# %%
from sklearn.linear_model import SGDRegressor
linear_model=SGDRegressor()
linear_model.fit(x_train,y_train)
# Out:
# SGDRegressor()

# %%
prediction=linear_model.predict(x_test);
prediction
# Out:
# array([-7.68703404e+13, -2.62016241e+14, -1.29503316e+14, -4.76587817e+13,
#        -9.66198616e+13, -2.69372449e+14, -4.02113818e+13, -9.96912113e+13,
#        -3.01062481e+14, -1.74931875e+14, -2.11317001e+14, -3.73761453e+14,
#        -3.98675717e+14, -3.19059199e+14, -3.52192436e+14, -1.08051982e+14,
#        -1.70147790e+14, -1.04179810e+14, -3.28356700e+14, -7.55645380e+13,
#        -1.88290428e+14, -1.53938936e+14, -4.57382526e+14, -4.05217916e+14,
#        -4.15797863e+14, -3.57252767e+14, -1.80296568e+14, -1.55270999e+14,
#        -3.40536251e+14, -9.74090552e+13, -3.14679305e+14, -1.81583569e+14,
#        -1.36258903e+14, -2.47740542e+14, -2.12690496e+14, -3.74652987e+13,
#        -2.57853008e+14, -9.84248707e+13, -3.06392667e+13, -2.77697409e+14,
#        -4.83344203e+13, -3.69475737e+14, -4.41249096e+14, -4.68182984e+14,
#        -2.03763799e+14, -1.76300220e+14,  1.23503102e+12, -4.49662560e+14,
# ...

# %%
#checking for outliers
from scipy import stats
z=np.abs(stats.zscore(train['Sale_Price']))
print(z)
# Out:
# 0       0.346887
# 1       0.006998
# 2       0.535714
# 3       0.515424
# 4       0.869309
#           ...
# 1454    0.051058
# 1455    0.074827
# 1456    0.365770
# 1457    1.077019
# 1458    0.488674
# Name: Sale_Price, Length: 1459, dtype: float64

# %%
#threshold=3

print(np.where(z>3))
# Out:
# (array([  58,  178,  185,  349,  389,  440,  473,  496,  527,  591,  664,
#         691,  769,  798,  803,  898, 1046, 1142, 1169, 1182, 1243, 1373],
#       dtype=int64),)

# %%
#dropping the outliers by using the z-score the outliers are chkecked in the dependent varibales[sale_price]
new_data=train.drop([58,  178,  185,  349,  389,  440,  473,  496,  527,  591,  664,
        691,  769,  798,  803,  898, 1046, 1142, 1169, 1182, 1243, 1373])

# %%
new_data.head()
# Out:
#    Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0   1              60          RLD        65.0      8450     Paved       NaN
# 1   2              20          RLD        80.0      9600     Paved       NaN
# 2   3              60          RLD        68.0     11250     Paved       NaN
# 3   4              70          RLD        60.0      9550     Paved       NaN
# 4   5              60          RLD        84.0     14260     Paved       NaN
#
#   Property_Shape Land_Outline Utility_Type  ... Pool_Area Pool_Quality  \
# 0            Reg          Lvl       AllPub  ...         0          NaN
# 1            Reg          Lvl       AllPub  ...         0          NaN
# 2            IR1          Lvl       AllPub  ...         0          NaN
# 3            IR1          Lvl       AllPub  ...         0          NaN
# 4            IR1          Lvl       AllPub  ...         0          NaN
#
#   Fence_Quality Miscellaneous_Feature Miscellaneous_Value Month_Sold  \
# ...

# %%
new_data.shape
# Out:
# (1437, 81)

# %%
X=train_df.drop(['Sale_Price'],axis=1)
Y=train_df['Sale_Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=.30)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1021, 252), (438, 252), (1021,), (438,))

# %%
from statsmodels.api import OLS
model_defination=OLS(y_train,x_train)
model_building_1=model_defination.fit()
print(model_building_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Sale_Price   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                     49.36
# Date:                Wed, 15 Feb 2023   Prob (F-statistic):               0.00
# Time:                        20:35:50   Log-Likelihood:                 2187.7
# No. Observations:                1021   AIC:                            -3911.
# Df Residuals:                     789   BIC:                            -2768.
# Df Model:                         231
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# index                       3.078e-09   1.36e-06      0.002      0.998   -2.66e-06    2.67e-06
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 1459 to 2917
# Columns: 253 entries, index to Sale_Condition_Partial
# dtypes: float64(32), int64(5), uint8(216)
# memory usage: 729.6 KB

# %%
#As once the validation is done x_test and y_test[as there is two datsets one is for train and test hence I
#validated on x_test and y-test]

#we are dropping saleprice from test dataset and adding a clumn with predcited values
#to test dataset
test_df=test_df.drop(['Sale_Price'],axis=1)

# %%
model_building_1.predict(test_df)
# Out:
# 1459    0.111729
# 1460    0.162453
# 1461    0.186113
# 1462    0.200773
# 1463    0.245762
#           ...
# 2913    1.004988
# 2914    0.987188
# 2915    0.168135
# 2916    0.085909
# 2917    0.257303
# Length: 1459, dtype: float64

# %%
#Adding column to test dataset as predicted_values of the sale_price
test_df['Predicted_values']=model_building_1.predict(test_df);
test_df['Predicted_values']
# Out:
# 1459    0.111729
# 1460    0.162453
# 1461    0.186113
# 1462    0.200773
# 1463    0.245762
#           ...
# 2913    1.004988
# 2914    0.987188
# 2915    0.168135
# 2916    0.085909
# 2917    0.257303
# Name: Predicted_values, Length: 1459, dtype: float64

# %%
test_df.head()
# Out:
#       index  Lot_Extent  Lot_Size  Construction_Year  Remodel_Year  \
# 1459   1459    0.202055  0.092797           0.644928      0.183333
# 1460   1460    0.205479  0.090676           0.623188      0.133333
# 1461   1461    0.181507  0.036967           0.905797      0.800000
# 1462   1462    0.195205  0.042005           0.913043      0.800000
# 1463   1463    0.075342  0.033309           0.869565      0.700000
#
#       Brick_Veneer_Area  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 1459             0.0000    0.082920    0.094364   0.115582
# 1460             0.0675    0.163536    0.000000   0.173801
# 1461             0.0000    0.140149    0.000000   0.058647
# 1462             0.0125    0.106662    0.000000   0.138699
# 1463             0.0000    0.046598    0.000000   0.435360
#
#       Total_Basement_Area  ...  Sale_Type_Oth  Sale_Type_WD  \
# 1459             0.144354  ...              0             1
# 1460             0.217512  ...              0             1
# ...

# %%
#Here we inverse scaling the predicted sales_price

# %%
sale_price_range=train['Sale_Price'].max()-train['Sale_Price'].min();
sale_price_range
# Out:
# 720100

# %%
test_df['Predicted_values']=test_df['Predicted_values']*sale_price_range+(train['Sale_Price'].min())

# %%
test_df
# Out:
#       index  Lot_Extent  Lot_Size  Construction_Year  Remodel_Year  \
# 1459   1459    0.202055  0.092797           0.644928      0.183333
# 1460   1460    0.205479  0.090676           0.623188      0.133333
# 1461   1461    0.181507  0.036967           0.905797      0.800000
# 1462   1462    0.195205  0.042005           0.913043      0.800000
# 1463   1463    0.075342  0.033309           0.869565      0.700000
# ...     ...         ...       ...                ...           ...
# 2913   2913    0.000000  0.085873           0.710145      0.333333
# 2914   2914    0.000000  0.056207           0.710145      0.333333
# 2915   2915    0.476027  0.052995           0.637681      0.766667
# 2916   2916    0.140411  0.029467           0.869565      0.700000
# 2917   2917    0.181507  0.047918           0.876812      0.733333
#
#       Brick_Veneer_Area  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 1459            0.00000    0.082920    0.094364   0.115582
# ...
